# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_excel("Dataset1.xlsx")

# %%
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1      0.411785     29172.0     191.272750  0.783968  0.984986   0.887034
# 2      0.562727     29690.0     193.410904  0.778113  0.989559   0.947849
# 3      0.498616     30724.0     195.467062  0.782681  0.976696   0.903936
# 4      0.333680     30417.0     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# ...

# %%
df.shape
# Out:
# (13611, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13606 non-null  float64
#  3   MinorAxisLength  13609 non-null  float64
#  4   AspectRation     13608 non-null  float64
#  5   Eccentricity     13608 non-null  float64
#  6   ConvexArea       13610 non-null  float64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13608 non-null  float64
#  9   Solidity         13610 non-null  float64
#  10  roundness        13608 non-null  float64
#  11  Compactness      13609 non-null  float64
#  12  ShapeFactor1     13609 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13611.000000  13611.000000     13606.000000     13609.000000
# mean    53048.284549    855.283459       320.157483       202.271934
# std     29324.095717    214.289696        85.704732        44.973272
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36328.000000    703.523500       253.301679       175.842829
# 50%     44652.000000    794.941000       296.909450       192.431733
# 75%     61332.000000    977.213000       376.507661       217.033886
# max    254616.000000   1985.370000       738.860153       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13608.000000  13608.000000   13610.000000   13611.000000  13608.000000
# mean       1.583306      0.750929   53769.027921     253.064220      0.749727
# std        0.246650      0.091961   29775.853140      59.177120      0.049089
# ...

# %% [markdown]
# **1.	Calculate the mean, median, and standard deviation for the "Area" and "Perimeter" columns. What do these values indicate about the distribution of these features?**

# %%
#mean of column Area
df['Area'].mean()
# Out:
# 53048.284549261625

# %%
#Median of column Area
df['Area'].median()
# Out:
# 44652.0

# %%
#Standard deviation of column Area
df['Area'].std()
# Out:
# 29324.095716881915

# %% [markdown]
# the mean of column area is 53048.284549261625, the median is 44652.0. Here the mean value is greater than median value so the dataset is a right skewed dataset. the standard deviation for this datset is 29324.095716881915. so the variance is very high.

# %%
#mean of column Perimeter
df['Perimeter'].mean()
# Out:
# 855.283458599662

# %%
#median of column Perimeter
df['Perimeter'].median()
# Out:
# 794.9409999999999

# %%
#Standard deviation of column Perimeter
df['Perimeter'].std()
# Out:
# 214.28969589196163

# %% [markdown]
# the mean of column area is 855.283458599662, the median is 794.9409999999999. Here the mean value is greater than median value so the dataset is a right scewed dataset. the standard deviation for this datset is 214.28969589196163
# . so thedataset have  a right skewed distributionh.

# %% [markdown]
# 4.	**How many unique "Class" categories are present in the dataset?**

# %%
# unique values in "Class" column
df['Class'].unique()
# Out:
# array(['SEKER', 'BARBUNYA', 'BOMBAY', 'CALI', 'HOROZ', 'SIRA', 'DERMASON'],
#       dtype=object)

# %%
df['Class'].nunique()
# Out:
# 7

# %% [markdown]
# There are 7 unique values in the column "Class". they are 'SEKER', 'BARBUNYA', 'BOMBAY', 'CALI', 'HOROZ', 'SIRA', 'DERMASON'.

# %% [markdown]
# **6. Is there a relationship between "Area" and "Perimeter"? Use a scatter plot to visualize this relationship and calculate the correlation coefficient?**

# %%
# Relationship between Area and Perimeter
plt.figure(figsize=(8,5))
sns.scatterplot(x='Area', y='Perimeter', data=df)
plt.title('Relationship between Area and Perimeter')
plt.show()

# %% [markdown]
# The plot shows the relation ship between the perimeter and Area.  from this plot we can find that there is a linear relationship between Area and Perimeter.

# %% [markdown]
# **10. Create a scatter plot for "Roundness" vs. "Compactness" for each class. What patterns can you identify from the scatter plot?**

# %%
# Relationship between Roundness and Compactness
plt.figure(figsize=(8,5))
sns.scatterplot(x='roundness', y='Compactness', data=df)
plt.title('Relationship between Roundness and Compactness')
plt.show()

# %% [markdown]
# The plot shows the relation ship between the Roundeness and Compactness. The most datas are in the right side of the graph. Most datas relys between the  0.7 and 1.

# %% [markdown]
# **7.	Create a boxplot for "Area" across different classes. What does the boxplot reveal about the distribution of "Area" for each class?**

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df['Area'])
plt.title('Outliers in Area')
plt.show()

# %% [markdown]
# **5.	Calculate the frequency distribution of each "Class." Which class appears the most, and which appears the least?**

# %%
freqplot = df.select_dtypes(include = ['float','int'])
freqplot.hist(figsize = (15,10))
plt.show()

# %% [markdown]
# **2.	Find the range and interquartile range (IQR) for "MajorAxisLength" and "MinorAxisLength." What do these values suggest about the shape of the objects in the dataset?**

# %%
column= df['MajorAxisLength'],['MinorAxisLength']
for column in df: 
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_whisker = Q1 - 1.5 * IQR
    upper_whisker = Q3 + 1.5 * IQR
    
    print(Q1)
    print(Q3)
# Out:
# 36328.0
# 61332.0
# 703.5234999999999
# 977.213
# 253.3016793945141
# 376.5076607941909
# 175.84282895360326
# 217.0338862580438
# 1.4323572388582018
# 1.7071867146132018
# 0.7159516593990953
# 0.8104852730287431
# 36713.75
# 62298.5
# 215.06800343677347
# 279.4464667024921
# 0.7186305818178506
# 0.7868511244426866
# 0.98567033012752
# 0.9900127855353295
# 0.8320527415464825
# 0.9168531632341574
# 0.7624492579061473
# 0.8342441674729055
# 0.005899859354582851
# 0.007271592499153608
# 0.0011535202279788705
# 0.0021702683011547387
# 0.581358590523898
# 0.6960062840466322
# 0.9937028954563084
# 0.9978825430406695
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[203], line 3
#       1 column= df['MajorAxisLength'],['MinorAxisLength']
#       2 for column in df:
# ----> 3     Q1 = df[column].quantile(0.25)
#       4     Q3 = df[column].quantile(0.75)
# ...
